# 4    /content/PCPD/Persian Car Plate Dataset/images...
# Name: image_path, dtype: object

# %%
def check_image_files(metadata):
    missing_files = []
    for _, row in metadata.iterrows():
        if not os.path.exists(row['image_path']):
            missing_files.append(row['image_path'])

    if missing_files:
        print(f"Warning: {len(missing_files)} image files are missing.")
        print("First few missing files:")
        print(missing_files[:5])
    else:
        print("All image files exist.")

check_image_files(metadata)
# Out:
# Warning: 6 image files are missing.
# First few missing files:
# ['/content/PCPD/Persian Car Plate Dataset/images/1888.jpeg', '/content/PCPD/Persian Car Plate Dataset/images/1889.jpeg', '/content/PCPD/Persian Car Plate Dataset/images/1890.jpeg', '/content/PCPD/Persian Car Plate Dataset/images/1888.jpeg', '/content/PCPD/Persian Car Plate Dataset/images/1889.jpeg']

# %%
print(f"befor filter : {len(metadata)}")
metadata = metadata[metadata['image_path'].apply(os.path.exists)]
print(f"after filter : {len(metadata)}")
# Out:
# befor filter : 1194
# after filter : 1188

# %%
label_encoders = {}
categorical_columns = ['CarModel','Color','Status']

for column in categorical_columns:
    le = LabelEncoder()
    metadata[f'{column}_encoded'] = le.fit_transform(metadata[column])
    label_encoders[column] = le

# %%
train_data, val_data = train_test_split(metadata, test_size=0.2, random_state=42)

# %%
img_size = (224, 224)
batch_size = 32

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=False,
    fill_mode='nearest',
    brightness_range=[0.8, 1.2],
    channel_shift_range=50.0
)

val_datagen = ImageDataGenerator(rescale=1./255)

from tensorflow.keras.preprocessing.image import load_img, img_to_array

def preprocess_image(image_path, target_size=(224, 224)):
    img = load_img(image_path, target_size=target_size)
    img_array = img_to_array(img)
    img_array = img_array / 255.0
    return img_array

def data_generator(data, batch_size, is_training=True):
    while True:
        for i in range(0, len(data), batch_size):
            batch_data = data.iloc[i:i+batch_size]
            batch_images = []
            batch_labels = {col: [] for col in categorical_columns}

            for _, row in batch_data.iterrows():
                img = preprocess_image(row['image_path'])
                batch_images.append(img)

                for col in categorical_columns:
                    batch_labels[col].append(label_encoders[col].transform([row[col]])[0])

            batch_images = np.array(batch_images)
            for col in categorical_columns:
                batch_labels[col] = np.array(batch_labels[col])

            yield batch_images, batch_labels

# %%
class AttentionLayer(layers.Layer):
    def __init__(self):
        super(AttentionLayer, self).__init__()

    def build(self, input_shape):
        self.W = self.add_weight(name="att_weight", shape=(input_shape[-1], 1),
                                 initializer="normal")
        self.b = self.add_weight(name="att_bias", shape=(1,),
                                 initializer="zeros")
        super(AttentionLayer, self).build(input_shape)

    def call(self, x):
        et = tf.keras.backend.tanh(tf.keras.backend.dot(x, self.W) + self.b)
        at = tf.keras.backend.softmax(et, axis=1)
        output = x * at
        return output

    def compute_output_shape(self, input_shape):
        return input_shape

base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

inputs = layers.Input(shape=(224, 224, 3))
x = base_model(inputs, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(1024, activation='relu')(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(512, activation='relu')(x)
x = layers.Dropout(0.3)(x)
x = AttentionLayer()(x)

outputs = {}
for column in categorical_columns:
    num_classes = len(label_encoders[column].classes_)
    outputs[column] = layers.Dense(num_classes, activation='softmax', name=column)(x)

model = models.Model(inputs=inputs, outputs=outputs)

loss_weights = {
    'CarModel': 1.5,
    'Color': 1.0,
    'Status': 1.0,
}

model.compile(optimizer='adam',
              loss={col: 'sparse_categorical_crossentropy' for col in categorical_columns},
              loss_weights=loss_weights,
              metrics={col: 'accuracy' for col in categorical_columns})

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6)

history = model.fit(
    data_generator(train_data, batch_size),
    steps_per_epoch=len(train_data) // batch_size,
    epochs=100,
    validation_data=data_generator(val_data, batch_size, is_training=False),
    validation_steps=len(val_data) // batch_size,
    callbacks=[reduce_lr]
)
# Out:
# Epoch 1/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 109s 699ms/step - CarModel_accuracy: 0.1528 - Color_accuracy: 0.2957 - Status_accuracy: 0.7265 - loss: 8.2705 - val_CarModel_accuracy: 0.0893 - val_Color_accuracy: 0.2098 - val_Status_accuracy: 0.4554 - val_loss: 8.7164 - learning_rate: 0.0010
# Epoch 2/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 83s 587ms/step - CarModel_accuracy: 0.4853 - Color_accuracy: 0.5789 - Status_accuracy: 0.9323 - loss: 4.8888 - val_CarModel_accuracy: 0.0146 - val_Color_accuracy: 0.2282 - val_Status_accuracy: 0.4757 - val_loss: 9.3070 - learning_rate: 0.0010
# Epoch 3/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 365ms/step - CarModel_accuracy: 0.6967 - Color_accuracy: 0.7020 - Status_accuracy: 0.9642 - loss: 3.0634 - val_CarModel_accuracy: 0.0146 - val_Color_accuracy: 0.2136 - val_Status_accuracy: 0.5340 - val_loss: 10.3085 - learning_rate: 0.0010
# Epoch 4/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 338ms/step - CarModel_accuracy: 0.8042 - Color_accuracy: 0.8146 - Status_accuracy: 0.9618 - loss: 1.8951 - val_CarModel_accuracy: 0.0049 - val_Color_accuracy: 0.0146 - val_Status_accuracy: 0.5097 - val_loss: 10.4648 - learning_rate: 0.0010
# Epoch 5/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 331ms/step - CarModel_accuracy: 0.8728 - Color_accuracy: 0.8075 - Status_accuracy: 0.9583 - loss: 1.4804 - val_CarModel_accuracy: 0.0000e+00 - val_Color_accuracy: 0.0097 - val_Status_accuracy: 0.4612 - val_loss: 10.9858 - learning_rate: 0.0010
# Epoch 6/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 367ms/step - CarModel_accuracy: 0.9259 - Color_accuracy: 0.8728 - Status_accuracy: 0.9635 - loss: 1.0366 - val_CarModel_accuracy: 0.0000e+00 - val_Color_accuracy: 0.0097 - val_Status_accuracy: 0.5583 - val_loss: 12.9067 - learning_rate: 0.0010
# Epoch 7/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 368ms/step - CarModel_accuracy: 0.9378 - Color_accuracy: 0.8938 - Status_accuracy: 0.9591 - loss: 0.7899 - val_CarModel_accuracy: 0.0097 - val_Color_accuracy: 0.0000e+00 - val_Status_accuracy: 0.5388 - val_loss: 12.8304 - learning_rate: 2.0000e-04
# Epoch 8/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 368ms/step - CarModel_accuracy: 0.9722 - Color_accuracy: 0.9646 - Status_accuracy: 0.9754 - loss: 0.3920 - val_CarModel_accuracy: 0.0000e+00 - val_Color_accuracy: 0.0000e+00 - val_Status_accuracy: 0.5194 - val_loss: 13.2365 - learning_rate: 2.0000e-04
# Epoch 9/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 336ms/step - CarModel_accuracy: 0.9839 - Color_accuracy: 0.9723 - Status_accuracy: 1.0000 - loss: 0.2512 - val_CarModel_accuracy: 0.0000e+00 - val_Color_accuracy: 0.0089 - val_Status_accuracy: 0.5446 - val_loss: 13.6011 - learning_rate: 2.0000e-04
# Epoch 10/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 352ms/step - CarModel_accuracy: 0.9872 - Color_accuracy: 0.9762 - Status_accuracy: 0.9982 - loss: 0.2096 - val_CarModel_accuracy: 0.0049 - val_Color_accuracy: 0.0194 - val_Status_accuracy: 0.5049 - val_loss: 14.4567 - learning_rate: 2.0000e-04
# Epoch 11/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 359ms/step
- val_CarModel_accuracy: 0.8301 - val_Color_accuracy: 0.8252 - val_Status_accuracy: 0.9806 - val_loss: 2.3417 - learning_rate: 1.0000e-06
# Epoch 73/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 356ms/step - CarModel_accuracy: 0.9969 - Color_accuracy: 0.9915 - Status_accuracy: 1.0000 - loss: 0.0926 - val_CarModel_accuracy: 0.8348 - val_Color_accuracy: 0.8304 - val_Status_accuracy: 0.9821 - val_loss: 2.3326 - learning_rate: 1.0000e-06
# Epoch 74/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 365ms/step - CarModel_accuracy: 1.0000 - Color_accuracy: 0.9956 - Status_accuracy: 0.9992 - loss: 0.0677 - val_CarModel_accuracy: 0.8155 - val_Color_accuracy: 0.8107 - val_Status_accuracy: 0.9854 - val_loss: 2.6018 - learning_rate: 1.0000e-06
# Epoch 75/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 360ms/step - CarModel_accuracy: 0.9871 - Color_accuracy: 0.9942 - Status_accuracy: 0.9983 - loss: 0.1024 - val_CarModel_accuracy: 0.8107 - val_Color_accuracy: 0.8447 - val_Status_accuracy: 0.9806 - val_loss: 2.5380 - learning_rate: 1.0000e-06
# Epoch 76/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 9s 332ms/step - CarModel_accuracy: 0.9990 - Color_accuracy: 0.9971 - Status_accuracy: 1.0000 - loss: 0.0720 - val_CarModel_accuracy: 0.8204 - val_Color_accuracy: 0.8301 - val_Status_accuracy: 0.9951 - val_loss: 2.4685 - learning_rate: 1.0000e-06
# Epoch 77/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 359ms/step - CarModel_accuracy: 0.9959 - Color_accuracy: 0.9876 - Status_accuracy: 0.9997 - loss: 0.0915 - val_CarModel_accuracy: 0.8301 - val_Color_accuracy: 0.8350 - val_Status_accuracy: 0.9854 - val_loss: 2.5052 - learning_rate: 1.0000e-06
# Epoch 78/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 352ms/step - CarModel_accuracy: 0.9967 - Color_accuracy: 0.9925 - Status_accuracy: 0.9960 - loss: 0.1008 - val_CarModel_accuracy: 0.8495 - val_Color_accuracy: 0.8301 - val_Status_accuracy: 0.9806 - val_loss: 2.3410 - learning_rate: 1.0000e-06
# Epoch 79/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 356ms/step - CarModel_accuracy: 0.9996 - Color_accuracy: 0.9908 - Status_accuracy: 1.0000 - loss: 0.0704 - val_CarModel_accuracy: 0.8204 - val_Color_accuracy: 0.8155 - val_Status_accuracy: 0.9806 - val_loss: 2.6320 - learning_rate: 1.0000e-06
# Epoch 80/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 360ms/step - CarModel_accuracy: 0.9984 - Color_accuracy: 0.9971 - Status_accuracy: 0.9996 - loss: 0.0694 - val_CarModel_accuracy: 0.8350 - val_Color_accuracy: 0.8252 - val_Status_accuracy: 0.9806 - val_loss: 2.3452 - learning_rate: 1.0000e-06
# Epoch 81/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 9s 333ms/step - CarModel_accuracy: 0.9987 - Color_accuracy: 0.9926 - Status_accuracy: 0.9991 - loss: 0.0703 - val_CarModel_accuracy: 0.8348 - val_Color_accuracy: 0.8259 - val_Status_accuracy: 0.9821 - val_loss: 2.3332 - learning_rate: 1.0000e-06
# Epoch 82/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 359ms/step - CarModel_accuracy: 0.9968 - Color_accuracy: 0.9938 - Status_accuracy: 0.9980 - loss: 0.0749 - val_CarModel_accuracy: 0.8204 - val_Color_accuracy: 0.8107 - val_Status_accuracy: 0.9854 - val_loss: 2.6066 - learning_rate: 1.0000e-06
# Epoch 83/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 361ms/step - CarModel_accuracy: 0.9960 - Color_accuracy: 0.9821 - Status_accuracy: 0.9953 - loss: 0.0972 - val_CarModel_accuracy: 0.8107 - val_Color_accuracy: 0.8447 - val_Status_accuracy: 0.9806 - val_loss: 2.5419 - learning_rate: 1.0000e-06
# Epoch 84/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 358ms/step - CarModel_accuracy: 0.9992 - Color_accuracy: 0.9894 - Status_accuracy: 0.9996 - loss: 0.0777 - val_CarModel_accuracy: 0.8155 - val_Color_accuracy: 0.8252 - val_Status_accuracy: 0.9903 - val_loss: 2.4717 - learning_rate: 1.0000e-06
# Epoch 85/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 357ms/step - CarModel_accuracy: 0.9967 - Color_accuracy: 0.9828 - Status_accuracy: 1.0000 - loss: 0.0801 - val_CarModel_accuracy: 0.8301 - val_Color_accuracy: 0.8301 - val_Status_accuracy: 0.9854 - val_loss: 2.5050 - learning_rate: 1.0000e-06
# Epoch 86/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 9s 325ms/step - CarModel_accuracy: 0.9991 - Color_accuracy: 0.9982 - Status_accuracy: 0.9971 - loss: 0.0772 - val_CarModel_accuracy: 0.8495 - val_Color_accuracy: 0.8252 - val_Status_accuracy: 0.9806 - val_loss: 2.3392 - learning_rate: 1.0000e-06
# Epoch 87/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 11s 386ms/step - CarModel_accuracy: 0.9980 - Color_accuracy: 0.9909 - Status_accuracy: 0.9993 - loss: 0.0717 - val_CarModel_accuracy: 0.8204 - val_Color_accuracy: 0.8107 - val_Status_accuracy: 0.9806 - val_loss: 2.6330 - learning_rate: 1.0000e-06
# Epoch 88/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 361ms/step - CarModel_accuracy: 0.9947 - Color_accuracy: 0.9972 - Status_accuracy: 0.9994 - loss: 0.0615 - val_CarModel_accuracy: 0.8350 - val_Color_accuracy: 0.8252 - val_Status_accuracy: 0.9806 - val_loss: 2.3458 - learning_rate: 1.0000e-06
# Epoch 89/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 364ms/step - CarModel_accuracy: 0.9990 - Color_accuracy: 0.9966 - Status_accuracy: 0.9997 - loss: 0.0750 - val_CarModel_accuracy: 0.8348 - val_Color_accuracy: 0.8304 - val_Status_accuracy: 0.9866 - val_loss: 2.3375 - learning_rate: 1.0000e-06
# Epoch 90/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 360ms/step - CarModel_accuracy: 0.9938 - Color_accuracy: 0.9918 - Status_accuracy: 0.9991 - loss: 0.0764 - val_CarModel_accuracy: 0.8204 - val_Color_accuracy: 0.8107 - val_Status_accuracy: 0.9854 - val_loss: 2.6114 - learning_rate: 1.0000e-06
# Epoch 91/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 338ms/step - CarModel_accuracy: 0.9985 - Color_accuracy: 0.9954 - Status_accuracy: 0.9987 - loss: 0.0687 - val_CarModel_accuracy: 0.8107 - val_Color_accuracy: 0.8447 - val_Status_accuracy: 0.9854 - val_loss: 2.5465 - learning_rate: 1.0000e-06
# Epoch 92/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 351ms/step - CarModel_accuracy: 0.9957 - Color_accuracy: 0.9874 - Status_accuracy: 0.9951 - loss: 0.0828 - val_CarModel_accuracy: 0.8204 - val_Color_accuracy: 0.8301 - val_Status_accuracy: 0.9951 - val_loss: 2.4759 - learning_rate: 1.0000e-06
# Epoch 93/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 357ms/step - CarModel_accuracy: 0.9984 - Color_accuracy: 0.9929 - Status_accuracy: 0.9962 - loss: 0.0744 - val_CarModel_accuracy: 0.8301 - val_Color_accuracy: 0.8350 - val_Status_accuracy: 0.9903 - val_loss: 2.5101 - learning_rate: 1.0000e-06
# Epoch 94/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 353ms/step - CarModel_accuracy: 0.9980 - Color_accuracy: 0.9950 - Status_accuracy: 0.9996 - loss: 0.0589 - val_CarModel_accuracy: 0.8447 - val_Color_accuracy: 0.8252 - val_Status_accuracy: 0.9806 - val_loss: 2.3405 - learning_rate: 1.0000e-06
# Epoch 95/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 354ms/step - CarModel_accuracy: 0.9983 - Color_accuracy: 0.9928 - Status_accuracy: 0.9963 - loss: 0.0817 - val_CarModel_accuracy: 0.8204 - val_Color_accuracy: 0.8155 - val_Status_accuracy: 0.9806 - val_loss: 2.6314 - learning_rate: 1.0000e-06
# Epoch 96/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 9s 327ms/step - CarModel_accuracy: 0.9974 - Color_accuracy: 0.9949 - Status_accuracy: 0.9995 - loss: 0.0683 - val_CarModel_accuracy: 0.8350 - val_Color_accuracy: 0.8252 - val_Status_accuracy: 0.9806 - val_loss: 2.3481 - learning_rate: 1.0000e-06
# Epoch 97/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 355ms/step - CarModel_accuracy: 0.9976 - Color_accuracy: 0.9901 - Status_accuracy: 0.9953 - loss: 0.0912 - val_CarModel_accuracy: 0.8348 - val_Color_accuracy: 0.8304 - val_Status_accuracy: 0.9821 - val_loss: 2.3362 - learning_rate: 1.0000e-06
# Epoch 98/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 361ms/step - CarModel_accuracy: 0.9967 - Color_accuracy: 0.9923 - Status_accuracy: 1.0000 - loss: 0.0631 - val_CarModel_accuracy: 0.8204 - val_Color_accuracy: 0.8107 - val_Status_accuracy: 0.9854 - val_loss: 2.6065 - learning_rate: 1.0000e-06
# Epoch 99/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 354ms/step - CarModel_accuracy: 0.9946 - Color_accuracy: 0.9898 - Status_accuracy: 0.9971 - loss: 0.0766 - val_CarModel_accuracy: 0.8107 - val_Color_accuracy: 0.8447 - val_Status_accuracy: 0.9806 - val_loss: 2.5391 - learning_rate: 1.0000e-06
# Epoch 100/100
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 346ms/step - CarModel_accuracy: 0.9964 - Color_accuracy: 0.9917 - Status_accuracy: 0.9991 - loss: 0.0871 - val_CarModel_accuracy: 0.8204 - val_Color_accuracy: 0.8301 - val_Status_accuracy: 0.9903 - val_loss: 2.4720 - learning_rate: 1.0000e-06

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    print(history.history.keys())

    plt.figure(figsize=(12, 5))
    plt.subplot(121)
    for key in history.history.keys():
        if 'acc' in key and 'val' not in key:
            plt.plot(history.history[key], label=key)
    for key in history.history.keys():
        if 'acc' in key and 'val' in key:
            plt.plot(history.history[key], label=key)
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(loc='lower right')

    plt.subplot(122)
    for key in history.history.keys():
        if 'loss' in key and 'val' not in key:
            plt.plot(history.history[key], label=key)
    for key in history.history.keys():
        if 'loss' in key and 'val' in key:
            plt.plot(history.history[key], label=key)
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(loc='upper right')

    plt.tight_layout()
    plt.show()

plot_training_history(history)
# Out:
# dict_keys(['CarModel_accuracy', 'Color_accuracy', 'Status_accuracy', 'loss', 'val_CarModel_accuracy', 'val_Color_accuracy', 'val_Status_accuracy', 'val_loss', 'learning_rate'])

# %%
model.save('/content/car_plate_model.keras')

# %%
def predict_car_info(image_path):
    img = tf.keras.preprocessing.image.load_img(image_path, target_size=img_size)
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array /= 255.0

    predictions = model.predict(img_array)

    results = {}
    for column, pred in zip(categorical_columns, predictions.values()):
        predicted_class = label_encoders[column].inverse_transform([np.argmax(pred[0])])[0]
        results[column] = predicted_class

    return results

# %%
import matplotlib.pyplot as plt

def predict_and_display_random_images(metadata, model, num_images=5):
    random_images = metadata.sample(n=num_images)

    plt.figure(figsize=(20, 6*num_images))

    for i, (_, row) in enumerate(random_images.iterrows()):
        img = tf.keras.preprocessing.image.load_img(row['image_path'], target_size=img_size)
        img_array = tf.keras.preprocessing.image.img_to_array(img)
        img_array = np.expand_dims(img_array, axis=0) / 255.0

        predictions = model.predict(img_array)

        results = {}
        for column, pred in zip(categorical_columns, predictions.values()):
            predicted_class = label_encoders[column].inverse_transform([np.argmax(pred[0])])[0]
            results[column] = predicted_class

        plt.subplot(num_images, 2, 2*i+1)
        plt.imshow(img)
        plt.axis('off')
        plt.title("Original Image")

        plt.subplot(num_images, 2, 2*i+2)
        plt.axis('off')
        plt.text(0.1, 0.9, "Predictions:", fontsize=12, fontweight='bold')
        for j, (key, value) in enumerate(results.items()):
            plt.text(0.1, 0.8 - j*0.1, f"{key}: {value}", fontsize=10)

        plt.text(0.6, 0.9, "Actual Values:", fontsize=12, fontweight='bold')
        for j, column in enumerate(categorical_columns):
            plt.text(0.6, 0.8 - j*0.1, f"{column}: {row[column]}", fontsize=10)

    plt.tight_layout()
    plt.show()

# Use the function to visualize predictions
predict_and_display_random_images(val_data, model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
